# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280068-collab/EPPL-ACT-26-profe/blob/main/EPPL_ACT_26_clse_Automovil_Christian_0068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Christian Garcia NL = 21 FEcha = 29/04/2026
# ________
#
# #### Clase Automovil con atributos 3, funciones leerdatos(), mostrardatos()
# -----
# #### Que sea interactivo ---> Los imput
# ----
# #### xrear obhetos carro 1, carro 2, carro 3
# ---
# #### No usar while, true, if, for, listas y diccionario
#
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280068-collab/EPPL-ACT-26-profe/refs/heads/main/automovilinfografia.png)

# %%
# Clase autovil, atributos, marca, placa, precio
# funciones leerdatos(), mostrardatos()
# crear 3 obhetos carro 1, carro 2, carro 3

class Automovil:
  def __init__(self, marca, placa, precio):
    self.marca = marca
    self.placa = placa
    self.precio = precio

  def leerdatos(self):
    self.marca = input("Ingrese la marca: ")
    self.placa = input("Ingrese la placa: ")
    self.precio = input("Ingrese el precio: ")
    return self.marca, self.placa, self.precio

  def mostrardatos(self):
    print(f"Marca",self.marca)
    print(f"Placa", self.placa)
    print(f"Preci", self.precio)
    return self.marca, self.placa, self.precio

# fin de  la clase automoil
# crear 3 obhetos carro 1, carro 2, carro 3

print("carro numer 1")
carro1 = Automovil("","","")
carro1 = Automovil.leerdatos()
carro1 = Automovil.mostrardatos()
print("")
print("carro numer 2")
carro2 = Automovil("","","")
carro2 = Automovil.leerdatos()
carro2 = Automovil.mostrardatos()
print("------------")
print("carro numer 3")
carro3 = Automovil("","","")
carro3 = Automovil.leerdatos()
carro3 = Automovil.mostrardatos()
print("programa realizado por Christian Garcia NL = 21")
# Out:
# carro numer 1
# Ingrese la marca: ford
# Ingrese la placa: 1234567
# Ingrese el precio: 80000
# Marca ford
# Placa 1234567
# Preci 80000
#
# carro numer 2
# Ingrese la marca: nissan
# Ingrese la placa: 7654321
# Ingrese el precio: 50000
# Marca nissan
# Placa 7654321
# Preci 50000
# ------------
# carro numer 3
# Ingrese la marca: mclaren
# Ingrese la placa: 2600000
# Ingrese el precio: 456000
# Marca mclaren
# Placa 2600000
# Preci 456000
# programa realizado por Christian Garcia NL = 21

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280068-collab/EPPL-ACT-26-profe/refs/heads/main/profe%20act%2026.png)
